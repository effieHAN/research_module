# %% [markdown]
# # Firm level data

# %%
import pandas as pd 
import numpy as np

# %%
# data=pd.read_csv("/Users/mengxi/Desktop/financial research/HAN/firm-county/ready_for_identified_affected_firm.csv")

path="/Users/effie/Desktop/term3/research_module/data/"
data=pd.read_csv(path+"firm_raw/ready_for_identified_affected_firm.csv")

# %%
data=data.reset_index().drop(['index'], axis=1)
data.index=data.index+1

data = data.loc[:, ~data.columns.str.contains('^Unnamed')]
data
# Out:
#           BvDID_firm  plz_firm  matching  kreisschluessel          kreis  \
# 1       DE2010000074     10178      1017            11000  Berlin, Stadt
# 2       DE2010000074     10178      1017            11000  Berlin, Stadt
# 3       DE2010000074     10178      1017            11000  Berlin, Stadt
# 4       DE2010000074     10178      1017            11000  Berlin, Stadt
# 5       DE2010000074     10178      1017            11000  Berlin, Stadt
# ...              ...       ...       ...              ...            ...
# 425095  DE8350276165     84339      8433             9277     Rottal-Inn
# 425096  DE8350276165     84339      8433             9277     Rottal-Inn
# 425097  DE8350276165     84339      8433             9277     Rottal-Inn
# 425098  DE8350277440     70469      7046             8111      Stuttgart
# 425099  DE8350277440     70469      7046             8111      Stuttgart
#
#                bundesland    year BvDID_bank_1  postcode_bank_1  data2025_1  \
# 1                  Berlin  2004.0      DE13216            60325    848006.0
# 2                  Berlin  2005.0      DE13216            60325   1425349.0
# 3                  Berlin  2007.0      DE13247            60329    432559.0
# 4                  Berlin  2008.0      DE13247            60329    327591.0
# 5                  Berlin  2009.0      DE13190            60311    605765.0
# ...                   ...     ...          ...              ...         ...
# 425095             Bayern  2012.0      DE13772            84307      1679.0
# 425096             Bayern  2013.0      DE13772            84307      1684.0
# 425097             Bayern  2014.0      DE13772            84307      1740.0
# 425098  Baden-Württemberg  2012.0      DE13352            83022      4175.0
# 425099  Baden-Württemberg  2013.0      DE13352            83022      4250.0
#
#         ...    culilev   loanlev     credlev     nclilev   ltdblev  \
# 1       ...  22.850683  1.062639   2782852.0  13183967.0       0.0
# 2       ...  12.455903  0.000000   3930375.0  14087308.0       0.0
# 3       ...  30.282000  0.000000   9386000.0  30841000.0  385000.0
# 4       ...  38.544000  0.000000   9515000.0  30351000.0   43000.0
# 5       ...  53.155000  0.000000  14610000.0  35291000.0  843000.0
# ...     ...        ...       ...         ...         ...       ...
# 425095  ...   1.299578  0.000000         0.0    351464.0  328864.0
# 425096  ...   1.614374  0.000000         0.0    385389.0  341517.0
# 425097  ...   2.527990  0.000000         0.0    371093.0  322595.0
# 425098  ...   0.056661  0.000000     52982.0      7500.0       0.0
# 425099  ...   2.293341  0.000000         0.0     40154.0       1.0
#
#            oncllev     wkcalev    shfdlev    random  random_sample_indicator
# 1       13183967.0  13066443.0  46.305570  0.210340                 0.569100
# 2       14087308.0   6997586.0  44.155380  0.975576                 0.569100
# 3       30456000.0  13859000.0  29.427000  0.683262                 0.569100
# 4       30308000.0  15419000.0  33.723000  0.797433                 0.569100
# 5       34448000.0  21978000.0  66.289000  0.788825                 0.569100
# ...            ...         ...        ...       ...                      ...
# 425095     22600.0   1085100.0   0.047464  0.552223                 0.642302
# 425096     43872.0    877202.0   0.000000  0.583665                 0.642302
# 425097     48498.0   1832555.0   0.000000  0.791019                 0.642302
# 425098      7500.0   1650209.0   2.513060  0.992052                 0.897052
# 425099     40153.0   2032051.0   0.104991  0.802052                 0.897052
#
# [425099 rows x 87 columns]

# %%
data = data.query('bank_type_1=="Savings banks"|bank_type_2=="Savings banks"|bank_type_3=="Savings banks"')

# data = data.query('bank_type_1=="Savings banks"')
# data = data.query('bank_type_2=="Savings banks"')
# data = data.query('bank_type_3=="Savings banks"')

data = data.query('2003<year<2013')

data=data.reset_index().drop(['index'], axis=1)
data.index=data.index+1

# %%
# data['year'].value_counts()

# %%
query_data = data.query('empl<20')
data.loc[:,'small'] = data.index.map(lambda x : 1 if x in query_data.index else 0)

query_data = data.query('year>2008')
data.loc[:,'year_post'] = data.index.map(lambda x : 1 if x in query_data.index else 0)

data
# Out:
#           BvDID_firm  plz_firm  matching  kreisschluessel            kreis  \
# 1       DE2010019552     90530      9053             9576             Roth
# 2       DE2010019552     90530      9053             9576             Roth
# 3       DE2010019552     90530      9053             9576             Roth
# 4       DE2010019739     15827      1582            12072   Teltow-Fläming
# 5       DE2010035090     12305      1230            11000    Berlin, Stadt
# ...              ...       ...       ...              ...              ...
# 148109  DE8350268089     85399      8539             9178         Freising
# 148110  DE8350273540     94362      9436             9278  Straubing-Bogen
# 148111  DE8350275036     84307      8430             9277       Rottal-Inn
# 148112  DE8350276165     84339      8433             9277       Rottal-Inn
# 148113  DE8350277440     70469      7046             8111        Stuttgart
#
#                bundesland    year BvDID_bank_1  postcode_bank_1  data2025_1  \
# 1                  Bayern  2010.0      DE13190            60311    623634.0
# 2                  Bayern  2011.0      DE13190            60311    527219.0
# 3                  Bayern  2012.0      DE13190            60311    525789.0
# 4             Brandenburg  2012.0      DE13124            10787      9839.0
# 5                  Berlin  2010.0      DE13885            30159     12353.0
# ...                   ...     ...          ...              ...         ...
# 148109             Bayern  2012.0      DE13338            85435      1835.0
# 148110             Bayern  2012.0      DE13732            84028      3268.0
# 148111             Bayern  2012.0      DE13772            84307      1679.0
# 148112             Bayern  2012.0      DE13772            84307      1679.0
# 148113  Baden-Württemberg  2012.0      DE13352            83022      4175.0
#
#         ...    credlev    nclilev    ltdblev   oncllev    wkcalev   shfdlev  \
# 1       ...  1788868.0  1803490.0  1548368.0  255122.0  1539373.0  1.206676
# 2       ...  1271838.0  2661218.0  1997714.0  663504.0  2039143.0  1.542198
# 3       ...  1006868.0  1929164.0  1695760.0  233404.0  1851245.0  1.738739
# 4       ...        NaN  1585586.0  1368936.0  216650.0        NaN  1.691839
# 5       ...        NaN   207252.0   204452.0    2800.0        NaN  0.023150
# ...     ...        ...        ...        ...       ...        ...       ...
# 148109  ...        0.0    67360.0        0.0   67360.0        0.0  0.183207
# 148110  ...        NaN     9000.0        0.0    9000.0        NaN  0.006883
# 148111  ...   137901.0   281000.0   281000.0       0.0    70215.0  0.000000
# 148112  ...        0.0   351464.0   328864.0   22600.0  1085100.0  0.047464
# 148113  ...    52982.0     7500.0        0.0    7500.0  1650209.0  2.513060
#
#           random random_sample_indicator  small  year_post
# 1       0.824339                0.627641      1          1
# 2       0.063830                0.627641      1          1
# 3       0.538877                0.627641      1          1
# 4       0.630216                0.540324      1          1
# 5       0.853153                0.741225      1          1
# ...          ...                     ...    ...        ...
# 148109  0.982878                0.733000      1          1
# 148110  0.832832                0.598721      1          1
# 148111  0.436713                0.500642      1          1
# 148112  0.552223                0.642302      1          1
# 148113  0.992052                0.897052      1          1
#
# [148113 rows x 89 columns]

# %%
# data['country_bank_1']=[x[:2] for x in data['BvDID_bank_1']]
# data = data.query('country_bank_1=="DE"')

# data['country_bank_2']=[x[:2] for x in data['BvDID_bank_2']]
# data = data.query('country_bank_2=="DE"')

# data['country_bank_3']=[x[:2] for x in data['BvDID_bank_3']]
# data = data.query('country_bank_3=="DE"')

data['postcode_bank_1'] = data['postcode_bank_1'].fillna(0)
data['postcode_bank_2'] = data['postcode_bank_2'].fillna(0)
data['postcode_bank_3'] = data['postcode_bank_3'].fillna(0)


data['postcode_bank_1'] = data['postcode_bank_1'].astype(str)
data['postcode_bank_2'] = data['postcode_bank_2'].astype(int)
data['postcode_bank_3'] = data['postcode_bank_3'].astype(int)

data['postcode_bank_2'] = data['postcode_bank_2'].astype(str)
data['postcode_bank_3'] = data['postcode_bank_3'].astype(str)

data['postcode_bank_1']=np.where(data['postcode_bank_1'].str.len()<5, "0"+data['postcode_bank_1'], data['postcode_bank_1'])
data['postcode_bank_2']=np.where(data['postcode_bank_2'].str.len()<5, "0"+data['postcode_bank_2'], data['postcode_bank_2'])
data['postcode_bank_3']=np.where(data['postcode_bank_3'].str.len()<5, "0"+data['postcode_bank_3'], data['postcode_bank_3'])



data=data.reset_index().drop(['index'], axis=1)
data.index=data.index+1

# %%
query_data = data.query('bank_type_1=="Savings banks"')
data.loc[:,'bank_ty_1'] = data.index.map(lambda x : 1 if x in query_data.index else 0)

query_data = data.query('bank_type_2=="Savings banks"')
data.loc[:,'bank_ty_2'] = data.index.map(lambda x : 1 if x in query_data.index else 0)

query_data = data.query('bank_type_3=="Savings banks"')
data.loc[:,'bank_ty_3'] = data.index.map(lambda x : 1 if x in query_data.index else 0)

# %%
data['post_affected_1_1']=[x[:1] for x in data['postcode_bank_1']]
data['post_affected_1_2']=[x[:1] for x in data['postcode_bank_2']]
data['post_affected_1_3']=[x[:1] for x in data['postcode_bank_3']]

data['post_affected_2_1']=[x[:2] for x in data['postcode_bank_1']]
data['post_affected_2_2']=[x[:2] for x in data['postcode_bank_2']]
data['post_affected_2_3']=[x[:2] for x in data['postcode_bank_3']]

# affected states: Sachsen, Nordrhein-Westfalen, Baden-Württemberg, Bayern, Hamburg, Schleswig-Holstein
# postcode of affected banks 
# 01 02 04 08 09
# 32 33 40 41 42 44 45 46 47 48151 48249 48282 48431 48599 48703 48653 49477 49525 50 51 52 53879 53937 53604 53111 57072 57462 57413 57439 57319 57392 57258 57271 58 59 
# 68 69 70 71 72 73 74 75 76646 76133 76530 76437 76275 77 78 79 88 89 97
# 63739 63897 8(80 81 82 83 84 85 86 87 88 89) 90 91 92 93 94 95 96 97 
data.loc[:,'bank_affected_23'] = data.index.map(lambda x : 1 if x in query_df_23.index else 0)

query_df_33 = data.query('post_affected_1_3=="8"|post_affected_2_3=="90"|post_affected_2_3=="91"|post_affected_2_3=="92"|post_affected_2_3=="93"|post_affected_2_3=="94"|post_affected_2_3=="95"|post_affected_2_3=="96"|post_affected_2_3=="97"|post_affected_2_3=="20"|post_affected_2_3=="22"|post_affected_2_3=="24"|post_affected_2_3=="25"|postcode_bank_3=="76646"|postcode_bank_3=="76133"|postcode_bank_3=="76530"|postcode_bank_3=="76437"|postcode_bank_3=="76275"|postcode_bank_3=="63739"|postcode_bank_3=="63897"|postcode_bank_3=="21073"|postcode_bank_3=="23701"|postcode_bank_3=="23909"|postcode_bank_3=="23552"')
data.loc[:,'bank_affected_33'] = data.index.map(lambda x : 1 if x in query_df_33.index else 0)


# 

query_df_1 = data.query('bank_affected_11==1|bank_affected_21==1|bank_affected_31==1')
data.loc[:,'bank_affected_1'] = data.index.map(lambda x : 1 if x in query_df_1.index else 0)

query_df_2 = data.query('bank_affected_12==1|bank_affected_22==1|bank_affected_32==1')
data.loc[:,'bank_affected_2'] = data.index.map(lambda x : 1 if x in query_df_2.index else 0)

query_df_3 = data.query('bank_affected_13==1|bank_affected_23==1|bank_affected_33==1')
data.loc[:,'bank_affected_3'] = data.index.map(lambda x : 1 if x in query_df_3.index else 0)

data
# Out:
#           BvDID_firm  plz_firm  matching  kreisschluessel            kreis  \
# 1       DE2010019552     90530      9053             9576             Roth
# 2       DE2010019552     90530      9053             9576             Roth
# 3       DE2010019552     90530      9053             9576             Roth
# 4       DE2010019739     15827      1582            12072   Teltow-Fläming
# 5       DE2010035090     12305      1230            11000    Berlin, Stadt
# ...              ...       ...       ...              ...              ...
# 148109  DE8350268089     85399      8539             9178         Freising
# 148110  DE8350273540     94362      9436             9278  Straubing-Bogen
# 148111  DE8350275036     84307      8430             9277       Rottal-Inn
# 148112  DE8350276165     84339      8433             9277       Rottal-Inn
# 148113  DE8350277440     70469      7046             8111        Stuttgart
#
#                bundesland    year BvDID_bank_1 postcode_bank_1  data2025_1  \
# 1                  Bayern  2010.0      DE13190           60311    623634.0
# 2                  Bayern  2011.0      DE13190           60311    527219.0
# 3                  Bayern  2012.0      DE13190           60311    525789.0
# 4             Brandenburg  2012.0      DE13124           10787      9839.0
# 5                  Berlin  2010.0      DE13885           30159     12353.0
# ...                   ...     ...          ...             ...         ...
# 148109             Bayern  2012.0      DE13338           85435      1835.0
# 148110             Bayern  2012.0      DE13732           84028      3268.0
# 148111             Bayern  2012.0      DE13772           84307      1679.0
# 148112             Bayern  2012.0      DE13772           84307      1679.0
# 148113  Baden-Württemberg  2012.0      DE13352           83022      4175.0
#
#         ...  bank_affected_31  bank_affected_12  bank_affected_22  \
# 1       ...                 0                 0                 0
# 2       ...                 0                 0                 0
# 3       ...                 0                 0                 0
# 4       ...                 0                 0                 0
# 5       ...                 0                 0                 0
# ...     ...               ...               ...               ...
# 148109  ...                 1                 0                 0
# 148110  ...                 1                 0                 0
# 148111  ...                 1                 0                 0
# 148112  ...                 1                 0                 0
# 148113  ...                 1                 0                 0
#
#         bank_affected_32  bank_affected_13 bank_affected_23  bank_affected_33  \
# 1                      0                 0                0                 1
# 2                      0                 0                0                 1
# 3                      0                 0                0                 1
# 4                      0                 0                0                 0
# 5                      0                 0                0                 0
# ...                  ...               ...              ...               ...
# 148109                 0                 0                0                 0
# 148110                 0                 0                0                 0
# 148111                 0                 0                0                 0
# 148112                 1                 0                0                 1
# 148113                 0                 0                0                 0
#
#        bank_affected_1 bank_affected_2  bank_affected_3
# 1                    0               0                1
# 2                    0               0                1
# 3                    0               0                1
# 4                    0               0                0
# 5                    0               0                0
# ...                ...             ...              ...
# 148109               1               0                0
# 148110               1               0                0
# 148111               1               0                0
# 148112               1               1                1
# 148113               1               0                0
#
# [148113 rows x 110 columns]

# %%
data['kreisschluessel'] = data['kreisschluessel'].astype(str)
data['kreisschluessel'] = np.where(data['kreisschluessel'].str.len()<5,"0"+data['kreisschluessel'],data['kreisschluessel'])

data
# Out:
#           BvDID_firm  plz_firm  matching kreisschluessel            kreis  \
# 1       DE2010019552     90530      9053           09576             Roth
# 2       DE2010019552     90530      9053           09576             Roth
# 3       DE2010019552     90530      9053           09576             Roth
# 4       DE2010019739     15827      1582           12072   Teltow-Fläming
# 5       DE2010035090     12305      1230           11000    Berlin, Stadt
# ...              ...       ...       ...             ...              ...
# 148109  DE8350268089     85399      8539           09178         Freising
# 148110  DE8350273540     94362      9436           09278  Straubing-Bogen
# 148111  DE8350275036     84307      8430           09277       Rottal-Inn
# 148112  DE8350276165     84339      8433           09277       Rottal-Inn
# 148113  DE8350277440     70469      7046           08111        Stuttgart
#
#                bundesland    year BvDID_bank_1 postcode_bank_1  data2025_1  \
# 1                  Bayern  2010.0      DE13190           60311    623634.0
# 2                  Bayern  2011.0      DE13190           60311    527219.0
# 3                  Bayern  2012.0      DE13190           60311    525789.0
# 4             Brandenburg  2012.0      DE13124           10787      9839.0
# 5                  Berlin  2010.0      DE13885           30159     12353.0
# ...                   ...     ...          ...             ...         ...
# 148109             Bayern  2012.0      DE13338           85435      1835.0
# 148110             Bayern  2012.0      DE13732           84028      3268.0
# 148111             Bayern  2012.0      DE13772           84307      1679.0
# 148112             Bayern  2012.0      DE13772           84307      1679.0
# 148113  Baden-Württemberg  2012.0      DE13352           83022      4175.0
#
#         ...  bank_affected_31  bank_affected_12  bank_affected_22  \
# 1       ...                 0                 0                 0
# 2       ...                 0                 0                 0
# 3       ...                 0                 0                 0
# 4       ...                 0                 0                 0
# 5       ...                 0                 0                 0
# ...     ...               ...               ...               ...
# 148109  ...                 1                 0                 0
# 148110  ...                 1                 0                 0
# 148111  ...                 1                 0                 0
# 148112  ...                 1                 0                 0
# 148113  ...                 1                 0                 0
#
#         bank_affected_32  bank_affected_13 bank_affected_23  bank_affected_33  \
# 1                      0                 0                0                 1
# 2                      0                 0                0                 1
# 3                      0                 0                0                 1
# 4                      0                 0                0                 0
# 5                      0                 0                0                 0
# ...                  ...               ...              ...               ...
# 148109                 0                 0                0                 0
# 148110                 0                 0                0                 0
# 148111                 0                 0                0                 0
# 148112                 1                 0                0                 1
# 148113                 0                 0                0                 0
#
#        bank_affected_1 bank_affected_2  bank_affected_3
# 1                    0               0                1
# 2                    0               0                1
# 3                    0               0                1
# 4                    0               0                0
# 5                    0               0                0
# ...                ...             ...              ...
# 148109               1               0                0
# 148110               1               0                0
# 148111               1               0                0
# 148112               1               1                1
# 148113               1               0                0
#
# [148113 rows x 110 columns]

# %%
data.columns
# Out:
# Index(['BvDID_firm', 'plz_firm', 'matching', 'kreisschluessel', 'kreis',
#        'bundesland', 'year', 'BvDID_bank_1', 'postcode_bank_1', 'data2025_1',
#        ...
#        'bank_affected_31', 'bank_affected_12', 'bank_affected_22',
#        'bank_affected_32', 'bank_affected_13', 'bank_affected_23',
#        'bank_affected_33', 'bank_affected_1', 'bank_affected_2',
#        'bank_affected_3'],
#       dtype='object', length=110)

# %%
data=data[['BvDID_firm', 'year', 'plz_firm', 'kreis', 'kreisschluessel', 'bundesland', 'BvDID_bank_1', 'postcode_bank_1', 'data2025_1',
       'data2075_1', 'data11750_1', 'data30680_1', 'data30690_1',
       'data38250_1', 'bank_type_1', 'liquidity_1', 'BvDID_bank_2',
       'postcode_bank_2', 'data2025_2', 'data2075_2', 'data11750_2',
       'data30680_2', 'data30690_2', 'data38250_2', 'bank_type_2',
       'liquidity_2', 'BvDID_bank_3', 'postcode_bank_3', 'data2025_3',
       'data2075_3', 'data11750_3', 'data30680_3', 'data30690_3',
       'data38250_3', 'bank_type_3', 'liquidity_3', 'fias', 'tfas', 'cash',
       'toas', 'shfd', 'ncli', 'ltdb', 'oncl', 'prov', 'culi', 'loan', 'cred',
       'wkca', 'ncas', 'empl', 'opre', 'turn', 'gros', 'staf', 'depr', 'cf',
       'rcem', 'rtas', 'dateinc_year_firm', 'sizecat', 'sector', 'adequacy',
       'hausbank', 'KID_firm', 'empllev', 'staflev', 'fiaslev', 'tfaslev',
       'cashlev', 'toaslev', 'provlev', 'ncaslev', 'turnlev', 'groslev',
       'deprlev', 'culilev', 'loanlev', 'credlev', 'nclilev', 'ltdblev',
       'oncllev', 'wkcalev', 'shfdlev', 'random', 'random_sample_indicator',
       'small', 'year_post', 'bank_ty_1', 'bank_ty_2', 'bank_ty_3',
       'bank_affected_1','bank_affected_2','bank_affected_3']]
data
# Out:
#           BvDID_firm    year  plz_firm            kreis kreisschluessel  \
# 1       DE2010019552  2010.0     90530             Roth           09576
# 2       DE2010019552  2011.0     90530             Roth           09576
# 3       DE2010019552  2012.0     90530             Roth           09576
# 4       DE2010019739  2012.0     15827   Teltow-Fläming           12072
# 5       DE2010035090  2010.0     12305    Berlin, Stadt           11000
# ...              ...     ...       ...              ...             ...
# 148109  DE8350268089  2012.0     85399         Freising           09178
# 148110  DE8350273540  2012.0     94362  Straubing-Bogen           09278
# 148111  DE8350275036  2012.0     84307       Rottal-Inn           09277
# 148112  DE8350276165  2012.0     84339       Rottal-Inn           09277
# 148113  DE8350277440  2012.0     70469        Stuttgart           08111
#
#                bundesland BvDID_bank_1 postcode_bank_1  data2025_1  \
# 1                  Bayern      DE13190           60311    623634.0
# 2                  Bayern      DE13190           60311    527219.0
# 3                  Bayern      DE13190           60311    525789.0
# 4             Brandenburg      DE13124           10787      9839.0
# 5                  Berlin      DE13885           30159     12353.0
# ...                   ...          ...             ...         ...
# 148109             Bayern      DE13338           85435      1835.0
# 148110             Bayern      DE13732           84028      3268.0
# 148111             Bayern      DE13772           84307      1679.0
# 148112             Bayern      DE13772           84307      1679.0
# 148113  Baden-Württemberg      DE13352           83022      4175.0
#
#         data2075_1  ...    random  random_sample_indicator  small  year_post  \
# 1         370294.0  ...  0.824339                 0.627641      1          1
# 2         307754.0  ...  0.063830                 0.627641      1          1
# 3         293639.0  ...  0.538877                 0.627641      1          1
# 4            644.0  ...  0.630216                 0.540324      1          1
# 5           1332.0  ...  0.853153                 0.741225      1          1
# ...            ...  ...       ...                      ...    ...        ...
# 148109       150.0  ...  0.982878                 0.733000      1          1
# 148110       564.0  ...  0.832832                 0.598721      1          1
# 148111       241.0  ...  0.436713                 0.500642      1          1
# 148112       241.0  ...  0.552223                 0.642302      1          1
# 148113       256.0  ...  0.992052                 0.897052      1          1
#
#        bank_ty_1  bank_ty_2 bank_ty_3 bank_affected_1  bank_affected_2  \
# 1              0          0         1               0                0
# 2              0          0         1               0                0
# 3              0          0         1               0                0
# 4              0          1         0               0                0
# 5              1          0         0               0                0
# ...          ...        ...       ...             ...              ...
# 148109         1          0         0               1                0
# 148110         1          0         0               1                0
# 148111         1          0         0               1                0
# 148112         1          0         0               1                1
# 148113         1          0         0               1                0
#
#         bank_affected_3
# 1                     1
# 2                     1
# 3                     1
# 4                     0
# 5                     0
# ...                 ...
# 148109                0
# 148110                0
# 148111                0
# 148112                1
# 148113                0
#
# [148113 rows x 94 columns]

# %%
data.eval('tyaf_1 = bank_ty_1 * bank_affected_1', inplace=True)
data.eval('tyaf_2 = bank_ty_2 * bank_affected_2', inplace=True)
data.eval('tyaf_3 = bank_ty_3 * bank_affected_3', inplace=True)

data
# Out:
#           BvDID_firm    year  plz_firm            kreis kreisschluessel  \
# 1       DE2010019552  2010.0     90530             Roth           09576
# 2       DE2010019552  2011.0     90530             Roth           09576
# 3       DE2010019552  2012.0     90530             Roth           09576
# 4       DE2010019739  2012.0     15827   Teltow-Fläming           12072
# 5       DE2010035090  2010.0     12305    Berlin, Stadt           11000
# ...              ...     ...       ...              ...             ...
# 148109  DE8350268089  2012.0     85399         Freising           09178
# 148110  DE8350273540  2012.0     94362  Straubing-Bogen           09278
# 148111  DE8350275036  2012.0     84307       Rottal-Inn           09277
# 148112  DE8350276165  2012.0     84339       Rottal-Inn           09277
# 148113  DE8350277440  2012.0     70469        Stuttgart           08111
#
#                bundesland BvDID_bank_1 postcode_bank_1  data2025_1  \
# 1                  Bayern      DE13190           60311    623634.0
# 2                  Bayern      DE13190           60311    527219.0
# 3                  Bayern      DE13190           60311    525789.0
# 4             Brandenburg      DE13124           10787      9839.0
# 5                  Berlin      DE13885           30159     12353.0
# ...                   ...          ...             ...         ...
# 148109             Bayern      DE13338           85435      1835.0
# 148110             Bayern      DE13732           84028      3268.0
# 148111             Bayern      DE13772           84307      1679.0
# 148112             Bayern      DE13772           84307      1679.0
# 148113  Baden-Württemberg      DE13352           83022      4175.0
#
#         data2075_1  ...  year_post  bank_ty_1  bank_ty_2  bank_ty_3  \
# 1         370294.0  ...          1          0          0          1
# 2         307754.0  ...          1          0          0          1
# 3         293639.0  ...          1          0          0          1
# 4            644.0  ...          1          0          1          0
# 5           1332.0  ...          1          1          0          0
# ...            ...  ...        ...        ...        ...        ...
# 148109       150.0  ...          1          1          0          0
# 148110       564.0  ...          1          1          0          0
# 148111       241.0  ...          1          1          0          0
# 148112       241.0  ...          1          1          0          0
# 148113       256.0  ...          1          1          0          0
#
#        bank_affected_1  bank_affected_2 bank_affected_3 tyaf_1  tyaf_2  tyaf_3
# 1                    0                0               1      0       0       1
# 2                    0                0               1      0       0       1
# 3                    0                0               1      0       0       1
# 4                    0                0               0      0       0       0
# 5                    0                0               0      0       0       0
# ...                ...              ...             ...    ...     ...     ...
# 148109               1                0               0      1       0       0
# 148110               1                0               0      1       0       0
# 148111               1                0               0      1       0       0
# 148112               1                1               1      1       0       0
# 148113               1                0               0      1       0       0
#
# [148113 rows x 97 columns]

# %%
query_bank_affected = data.query('tyaf_1==1|tyaf_2==1|tyaf_3==1')
data.loc[:,'bank_affected'] = data.index.map(lambda x : 1 if x in query_bank_affected.index else 0)

data.eval('bank_affected_degree = tyaf_1 + tyaf_2 + tyaf_3', inplace=True)
# Out:
# /Users/effie/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1596: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# /Users/effie/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1745: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)

# %%
data
# Out:
#           BvDID_firm    year  plz_firm            kreis kreisschluessel  \
# 1       DE2010019552  2010.0     90530             Roth           09576
# 2       DE2010019552  2011.0     90530             Roth           09576
# 3       DE2010019552  2012.0     90530             Roth           09576
# 4       DE2010019739  2012.0     15827   Teltow-Fläming           12072
# 5       DE2010035090  2010.0     12305    Berlin, Stadt           11000
# ...              ...     ...       ...              ...             ...
# 148109  DE8350268089  2012.0     85399         Freising           09178
# 148110  DE8350273540  2012.0     94362  Straubing-Bogen           09278
# 148111  DE8350275036  2012.0     84307       Rottal-Inn           09277
# 148112  DE8350276165  2012.0     84339       Rottal-Inn           09277
# 148113  DE8350277440  2012.0     70469        Stuttgart           08111
#
#                bundesland BvDID_bank_1 postcode_bank_1  data2025_1  \
# 1                  Bayern      DE13190           60311    623634.0
# 2                  Bayern      DE13190           60311    527219.0
# 3                  Bayern      DE13190           60311    525789.0
# 4             Brandenburg      DE13124           10787      9839.0
# 5                  Berlin      DE13885           30159     12353.0
# ...                   ...          ...             ...         ...
# 148109             Bayern      DE13338           85435      1835.0
# 148110             Bayern      DE13732           84028      3268.0
# 148111             Bayern      DE13772           84307      1679.0
# 148112             Bayern      DE13772           84307      1679.0
# 148113  Baden-Württemberg      DE13352           83022      4175.0
#
#         data2075_1  ...  bank_ty_2  bank_ty_3  bank_affected_1  \
# 1         370294.0  ...          0          1                0
# 2         307754.0  ...          0          1                0
# 3         293639.0  ...          0          1                0
# 4            644.0  ...          1          0                0
# 5           1332.0  ...          0          0                0
# ...            ...  ...        ...        ...              ...
# 148109       150.0  ...          0          0                1
# 148110       564.0  ...          0          0                1
# 148111       241.0  ...          0          0                1
# 148112       241.0  ...          0          0                1
# 148113       256.0  ...          0          0                1
#
#         bank_affected_2 bank_affected_3  tyaf_1 tyaf_2 tyaf_3  bank_affected  \
# 1                     0               1       0      0      1              1
# 2                     0               1       0      0      1              1
# 3                     0               1       0      0      1              1
# 4                     0               0       0      0      0              0
# 5                     0               0       0      0      0              0
# ...                 ...             ...     ...    ...    ...            ...
# 148109                0               0       1      0      0              1
# 148110                0               0       1      0      0              1
# 148111                0               0       1      0      0              1
# 148112                1               1       1      0      0              1
# 148113                0               0       1      0      0              1
#
#         bank_affected_degree
# 1                          1
# 2                          1
# 3                          1
# 4                          0
# 5                          0
# ...                      ...
# 148109                     1
# 148110                     1
# 148111                     1
# 148112                     1
# 148113                     1
#
# [148113 rows x 99 columns]

# %%
data['bank_affected'].value_counts()
# Out:
# 1    97932
# 0    50181
# Name: bank_affected, dtype: int64

# %%
data['bank_affected_degree'].value_counts()
# Out:
# 1    94017
# 0    50181
# 2     3794
# 3      121
# Name: bank_affected_degree, dtype: int64

# %%
data=data[['BvDID_firm', 'year', 'plz_firm', 'kreis', 'kreisschluessel', 'bundesland', 'BvDID_bank_1', 'postcode_bank_1', 'data2025_1',
       'data2075_1', 'data11750_1', 'data30680_1', 'data30690_1',
       'data38250_1', 'bank_type_1', 'liquidity_1', 'BvDID_bank_2',
       'postcode_bank_2', 'data2025_2', 'data2075_2', 'data11750_2',
       'data30680_2', 'data30690_2', 'data38250_2', 'bank_type_2',
       'liquidity_2', 'BvDID_bank_3', 'postcode_bank_3', 'data2025_3',
       'data2075_3', 'data11750_3', 'data30680_3', 'data30690_3',
       'data38250_3', 'bank_type_3', 'liquidity_3', 'fias', 'tfas', 'cash',
       'toas', 'shfd', 'ncli', 'ltdb', 'oncl', 'prov', 'culi', 'loan', 'cred',
       'wkca', 'ncas', 'empl', 'opre', 'turn', 'gros', 'staf', 'depr', 'cf',
       'rcem', 'rtas', 'dateinc_year_firm', 'sizecat', 'sector', 'adequacy',
       'hausbank', 'KID_firm', 'empllev', 'staflev', 'fiaslev', 'tfaslev',
       'cashlev', 'toaslev', 'provlev', 'ncaslev', 'turnlev', 'groslev',
       'deprlev', 'culilev', 'loanlev', 'credlev', 'nclilev', 'ltdblev',
       'oncllev', 'wkcalev', 'shfdlev', 'random', 'random_sample_indicator',
       'small', 'year_post', 'bank_ty_1', 'bank_ty_2', 'bank_ty_3',
       'bank_affected', 'bank_affected_degree']]
data
# Out:
#           BvDID_firm    year  plz_firm            kreis kreisschluessel  \
# 1       DE2010019552  2010.0     90530             Roth           09576
# 2       DE2010019552  2011.0     90530             Roth           09576
# 3       DE2010019552  2012.0     90530             Roth           09576
# 4       DE2010019739  2012.0     15827   Teltow-Fläming           12072
# 5       DE2010035090  2010.0     12305    Berlin, Stadt           11000
# ...              ...     ...       ...              ...             ...
# 148109  DE8350268089  2012.0     85399         Freising           09178
# 148110  DE8350273540  2012.0     94362  Straubing-Bogen           09278
# 148111  DE8350275036  2012.0     84307       Rottal-Inn           09277
# 148112  DE8350276165  2012.0     84339       Rottal-Inn           09277
# 148113  DE8350277440  2012.0     70469        Stuttgart           08111
#
#                bundesland BvDID_bank_1 postcode_bank_1  data2025_1  \
# 1                  Bayern      DE13190           60311    623634.0
# 2                  Bayern      DE13190           60311    527219.0
# 3                  Bayern      DE13190           60311    525789.0
# 4             Brandenburg      DE13124           10787      9839.0
# 5                  Berlin      DE13885           30159     12353.0
# ...                   ...          ...             ...         ...
# 148109             Bayern      DE13338           85435      1835.0
# 148110             Bayern      DE13732           84028      3268.0
# 148111             Bayern      DE13772           84307      1679.0
# 148112             Bayern      DE13772           84307      1679.0
# 148113  Baden-Württemberg      DE13352           83022      4175.0
#
#         data2075_1  ...   shfdlev    random  random_sample_indicator  small  \
# 1         370294.0  ...  1.206676  0.824339                 0.627641      1
# 2         307754.0  ...  1.542198  0.063830                 0.627641      1
# 3         293639.0  ...  1.738739  0.538877                 0.627641      1
# 4            644.0  ...  1.691839  0.630216                 0.540324      1
# 5           1332.0  ...  0.023150  0.853153                 0.741225      1
# ...            ...  ...       ...       ...                      ...    ...
# 148109       150.0  ...  0.183207  0.982878                 0.733000      1
# 148110       564.0  ...  0.006883  0.832832                 0.598721      1
# 148111       241.0  ...  0.000000  0.436713                 0.500642      1
# 148112       241.0  ...  0.047464  0.552223                 0.642302      1
# 148113       256.0  ...  2.513060  0.992052                 0.897052      1
#
#        year_post  bank_ty_1 bank_ty_2 bank_ty_3  bank_affected  \
# 1              1          0         0         1              1
# 2              1          0         0         1              1
# 3              1          0         0         1              1
# 4              1          0         1         0              0
# 5              1          1         0         0              0
# ...          ...        ...       ...       ...            ...
# 148109         1          1         0         0              1
# 148110         1          1         0         0              1
# 148111         1          1         0         0              1
# 148112         1          1         0         0              1
# 148113         1          1         0         0              1
#
#         bank_affected_degree
# 1                          1
# 2                          1
# 3                          1
# 4                          0
# 5                          0
# ...                      ...
# 148109                     1
# 148110                     1
# 148111                     1
# 148112                     1
# 148113                     1
#
# [148113 rows x 93 columns]

# %%
#data.to_csv(path_or_buf=r'/Users/mengxi/Desktop/financial research/final/211219 - data.csv')

# %%
data['ort_1'] = data['kreis'].str.replace("Bad Doberan", "Rostock, Landkreis", n=-1)
data['ort_2'] = data['ort_1'].str.replace("Güstrow", "Rostock, Landkreis", n=-1)

data['ort_3'] = data['ort_2'].str.replace("Demmin", "Mecklenburgische Seenplatte", n=-1)
data['ort_4'] = data['ort_3'].str.replace("Neubrandenburg", "Mecklenburgische Seenplatte", n=-1)
data['ort_5'] = data['ort_4'].str.replace("Müritz", "Mecklenburgische Seenplatte", n=-1)
data['ort_6'] = data['ort_5'].str.replace("Mecklenburg-Strelitz", "Mecklenburgische Seenplatte", n=-1)

data['ort_7'] = data['ort_6'].str.replace("Uecker-Randow", "Vorpommern-Greifswald", n=-1)
data['ort_8'] = data['ort_7'].str.replace("Ostvorpommern", "Vorpommern-Greifswald", n=-1)
data['ort_9'] = data['ort_8'].str.replace("Greifswald", "Vorpommern-Greifswald", n=-1)

data['ort_10'] = data['ort_9'].str.replace("Stralsund", "Vorpommern-Rügen", n=-1)
data['ort_11'] = data['ort_10'].str.replace("Nordvorpommern", "Vorpommern-Rügen", n=-1)
data['ort_12'] = data['ort_11'].str.replace("Rügen", "Vorpommern-Rügen", n=-1)

data['ort_13'] = data['ort_12'].str.replace("Wismar", "Nordwestmecklenburg", n=-1)

data['ort_14'] = data['ort_13'].str.replace("Parchim", "Ludwigslust-Parchim", n=-1)
data['ort_15'] = data['ort_14'].str.replace("Ludwigslust", "Ludwigslust-Parchim", n=-1)





data['ort_16'] = data['ort_15'].str.replace("Kamenz", "Bautzen", n=-1)
data['ort_17'] = data['ort_16'].str.replace("Hoyerswerda, Stadt", "Bautzen", n=-1)

data['ort_18'] = data['ort_17'].str.replace("Riesa-Großenhain", "Meißen", n=-1)

data['ort_19'] = data['ort_18'].str.replace("Weißeritzkreis", "Sächsische Schweiz-Osterzgebirge", n=-1)
data['ort_20'] = data['ort_19'].str.replace("Sächsische Schweiz", "Sächsische Schweiz-Osterzgebirge", n=-1)

data['ort_21'] = data['ort_20'].str.replace("Döbeln", "Mittelsachsen", n=-1)
data['ort_22'] = data['ort_21'].str.replace("Mittweida", "Mittelsachsen", n=-1)
data['ort_23'] = data['ort_22'].str.replace("Freiberg", "Mittelsachsen", n=-1)

data['ort_24'] = data['ort_23'].str.replace("Delitzsch", "Nordsachsen", n=-1)
data['ort_25'] = data['ort_24'].str.replace("Torgau-Oschatz", "Nordsachsen", n=-1)

data['ort_26'] = data['ort_25'].str.replace("Leipziger Land", "Leipzig, Landkreis", n=-1)
data['ort_27'] = data['ort_26'].str.replace("Muldentalkreis", "Leipzig, Landkreis", n=-1)

data['ort_28'] = data['ort_27'].str.replace("Chemnitzer Land", "Zwickau", n=-1)
data['ort_29'] = data['ort_28'].str.replace("Zwickauer Land", "Zwickau", n=-1)
data['ort_30'] = data['ort_29'].str.replace("Zwickau, Stadt", "Zwickau", n=-1)

data['ort_31'] = data['ort_30'].str.replace("Mittlerer Erzgebirgskreis", "Erzgebirgskreis", n=-1)
data['ort_32'] = data['ort_31'].str.replace("Annaberg", "Erzgebirgskreis", n=-1)
data['ort_33'] = data['ort_32'].str.replace("Stollberg", "Erzgebirgskreis", n=-1)
data['ort_34'] = data['ort_33'].str.replace("Aue-Schwarzenberg", "Erzgebirgskreis", n=-1)

data['ort_35'] = data['ort_34'].str.replace("Löbau-Zittau", "Görlitz", n=-1)
data['ort_36'] = data['ort_35'].str.replace("Görlitz, Stadt", "Görlitz", n=-1)
data['ort_37'] = data['ort_36'].str.replace("Niederschlesischer Oberlausitzkreis", "Görlitz", n=-1)

data['ort_38'] = data['ort_37'].str.replace("Plauen, Stadt", "Vogtlandkreis", n=-1)



data['ort_39'] = data['ort_38'].str.replace("Bitterfeld", "Anhalt-Bitterfeld", n=-1)
data['ort_40'] = data['ort_39'].str.replace("Köthen", "Anhalt-Bitterfeld", n=-1)

data['ort_41'] = data['ort_40'].str.replace("Dessau, Stadt", "Dessau-Roßlau", n=-1)

data['ort_42'] = data['ort_41'].str.replace("Bördekreis", "Börde", n=-1)
data['ort_43'] = data['ort_42'].str.replace("Ohrekreis", "Börde", n=-1)

data['ort_44'] = data['ort_43'].str.replace("Bernburg", "Salzlandkreis", n=-1)
data['ort_45'] = data['ort_44'].str.replace("Schönebeck", "Salzlandkreis", n=-1)
data['ort_46'] = data['ort_45'].str.replace("Aschersleben-Staßfurt", "Salzlandkreis", n=-1)

data['ort_47'] = data['ort_46'].str.replace("Weißenfels", "Burgenlandkreis", n=-1)

data['ort_48'] = data['ort_47'].str.replace("Merseburg-Querfurt", "Saalekreis", n=-1)
data['ort_49'] = data['ort_48'].str.replace("Saalkreis", "Saalekreis", n=-1)

data['ort_50'] = data['ort_49'].str.replace("Halberstadt", "Harz", n=-1)
data['ort_51'] = data['ort_50'].str.replace("Quedlinburg", "Harz", n=-1)
data['ort_52'] = data['ort_51'].str.replace("Wernigerode", "Harz", n=-1)

data['ort_53'] = data['ort_52'].str.replace("Anhalt-Zerbst", "Wittenberg", n=-1)

data['ort_54'] = data['ort_53'].str.replace("Halle (Saale), Stadt", "Halle (Saale)", n=-1)

data['ort_55'] = data['ort_54'].str.replace("Mansfelder Land", "Mansfeld-Südharz", n=-1)
data['ort'] = data['ort_55'].str.replace("Sangerhausen", "Mansfeld-Südharz", n=-1)
# Out:
# <ipython-input-20-ec6faf6ae130>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ort_1'] = data['kreis'].str.replace("Bad Doberan", "Rostock, Landkreis", n=-1)
# <ipython-input-20-ec6faf6ae130>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ort_2'] = data['ort_1'].str.replace("Güstrow", "Rostock, Landkreis", n=-1)
# <ipython-input-20-ec6faf6ae130>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ort_3'] = data['ort_2'].str.replace("Demmin", "Mecklenburgische Seenplatte", n=-1)
# <ipython-input-20-ec6faf6ae130>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ort_4'] = data['ort_3'].str.replace("Neubrandenburg", "Mecklenburgische Seenplatte", n=-1)
# <ipython-input-20-ec6faf6ae130>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ort_5'] = data['ort_4'].str.replace("Müritz", "Mecklenburgische Seenplatte", n=-1)

# %%
# data['regionalkey_1'] = data['kreisschluessel'].str.replace("Bad Doberan", "Rostock, Landkreis", n=-1)
# data['ort_2'] = data['ort_1'].str.replace("Güstrow", "Rostock, Landkreis", n=-1)

# data['ort_3'] = data['ort_2'].str.replace("Demmin", "Mecklenburgische Seenplatte", n=-1)
# data['ort_4'] = data['ort_3'].str.replace("Neubrandenburg", "Mecklenburgische Seenplatte", n=-1)
# data['ort_5'] = data['ort_4'].str.replace("Müritz", "Mecklenburgische Seenplatte", n=-1)
# data['ort_6'] = data['ort_5'].str.replace("Mecklenburg-Strelitz", "Mecklenburgische Seenplatte", n=-1)

# data['ort_7'] = data['ort_6'].str.replace("Uecker-Randow", "Vorpommern-Greifswald", n=-1)
# data['ort_8'] = data['ort_7'].str.replace("Ostvorpommern", "Vorpommern-Greifswald", n=-1)
# data['ort_9'] = data['ort_8'].str.replace("Greifswald", "Vorpommern-Greifswald", n=-1)

# data['ort_10'] = data['ort_9'].str.replace("Stralsund", "Vorpommern-Rügen", n=-1)
# data['ort_11'] = data['ort_10'].str.replace("Nordvorpommern", "Vorpommern-Rügen", n=-1)
# data['ort_12'] = data['ort_11'].str.replace("Rügen", "Vorpommern-Rügen", n=-1)

# data['ort_13'] = data['ort_12'].str.replace("Wismar", "Nordwestmecklenburg", n=-1)

# data['ort_14'] = data['ort_13'].str.replace("Parchim", "Ludwigslust-Parchim", n=-1)
# data['ort_15'] = data['ort_14'].str.replace("Ludwigslust", "Ludwigslust-Parchim", n=-1)


# regional key
data['regionalkey_1'] = data['kreisschluessel'].str.replace("13051", "13072", n=-1)
data['regionalkey_2'] = data['regionalkey_1'].str.replace("13053", "13072", n=-1)

data['regionalkey_3'] = data['regionalkey_2'].str.replace("13052", "13071", n=-1)
data['regionalkey_4'] = data['regionalkey_3'].str.replace("13002", "13071", n=-1)
data['regionalkey_5'] = data['regionalkey_4'].str.replace("13056", "13071", n=-1)
data['regionalkey_6'] = data['regionalkey_5'].str.replace("13055", "13071", n=-1)

data['regionalkey_7'] = data['regionalkey_6'].str.replace("13062", "13075", n=-1)
data['regionalkey_8'] = data['regionalkey_7'].str.replace("13059", "13075", n=-1)
data['regionalkey_9'] = data['regionalkey_8'].str.replace("13001", "13075", n=-1)

data['regionalkey_10'] = data['regionalkey_9'].str.replace("13005", "13073", n=-1)
data['regionalkey_11'] = data['regionalkey_10'].str.replace("13057", "13073", n=-1)
data['regionalkey_12'] = data['regionalkey_11'].str.replace("13061", "13073", n=-1)

data['regionalkey_13'] = data['regionalkey_12'].str.replace("13006", "13074", n=-1)
data['regionalkey_14'] = data['regionalkey_13'].str.replace("13058", "13074", n=-1)

data['regionalkey_15'] = data['regionalkey_14'].str.replace("13060", "13076", n=-1)
data['regionalkey_16'] = data['regionalkey_15'].str.replace("13054", "13076", n=-1)





data['regionalkey_17'] = data['regionalkey_16'].str.replace("14292", "14625", n=-1)
data['regionalkey_18'] = data['regionalkey_17'].str.replace("14262", "14625", n=-1)
data['regionalkey_19'] = data['regionalkey_18'].str.replace("14272", "14625", n=-1)

data['regionalkey_20'] = data['regionalkey_19'].str.replace("14285", "14627", n=-1)
data['regionalkey_21'] = data['regionalkey_20'].str.replace("14280", "14627", n=-1)

data['regionalkey_22'] = data['regionalkey_21'].str.replace("14290", "14628", n=-1)
data['regionalkey_23'] = data['regionalkey_22'].str.replace("14287", "14628", n=-1)

data['regionalkey_24'] = data['regionalkey_23'].str.replace("14375", "14522", n=-1)
data['regionalkey_25'] = data['regionalkey_24'].str.replace("14182", "14522", n=-1)
data['regionalkey_26'] = data['regionalkey_25'].str.replace("14177", "14522", n=-1)

data['regionalkey_27'] = data['regionalkey_26'].str.replace("14374", "14730", n=-1)
data['regionalkey_28'] = data['regionalkey_27'].str.replace("14389", "14730", n=-1)

data['regionalkey_29'] = data['regionalkey_28'].str.replace("14379", "14729", n=-1)
data['regionalkey_30'] = data['regionalkey_29'].str.replace("14383", "14729", n=-1)

data['regionalkey_31'] = data['regionalkey_30'].str.replace("14173", "14524", n=-1)
data['regionalkey_32'] = data['regionalkey_31'].str.replace("14193", "14524", n=-1)
data['regionalkey_33'] = data['regionalkey_32'].str.replace("14167", "14524", n=-1)

data['regionalkey_34'] = data['regionalkey_33'].str.replace("14181", "14521", n=-1)
data['regionalkey_35'] = data['regionalkey_34'].str.replace("14171", "14521", n=-1)
data['regionalkey_36'] = data['regionalkey_35'].str.replace("14188", "14521", n=-1)
data['regionalkey_37'] = data['regionalkey_36'].str.replace("14191", "14521", n=-1)

data['regionalkey_38'] = data['regionalkey_37'].str.replace("14286", "14626", n=-1)
data['regionalkey_39'] = data['regionalkey_38'].str.replace("14263", "14626", n=-1)
data['regionalkey_40'] = data['regionalkey_39'].str.replace("14284", "14626", n=-1)

data['regionalkey_41'] = data['regionalkey_40'].str.replace("14166", "14523", n=-1)
data['regionalkey_42'] = data['regionalkey_41'].str.replace("14178", "14523", n=-1)





data['regionalkey_43'] = data['regionalkey_42'].str.replace("15154", "15082", n=-1)
data['regionalkey_44'] = data['regionalkey_43'].str.replace("15159", "15082", n=-1)

data['regionalkey_45'] = data['regionalkey_44'].str.replace("15101", "15001", n=-1)

data['regionalkey_46'] = data['regionalkey_45'].str.replace("15355", "15083", n=-1)
data['regionalkey_47'] = data['regionalkey_46'].str.replace("15362", "15083", n=-1)

data['regionalkey_48'] = data['regionalkey_47'].str.replace("15153", "15089", n=-1)
data['regionalkey_49'] = data['regionalkey_48'].str.replace("15367", "15089", n=-1)
data['regionalkey_50'] = data['regionalkey_49'].str.replace("15352", "15089", n=-1)

data['regionalkey_51'] = data['regionalkey_50'].str.replace("15268", "15084", n=-1)
data['regionalkey_52'] = data['regionalkey_51'].str.replace("15256", "15084", n=-1)

data['regionalkey_53'] = data['regionalkey_52'].str.replace("15261", "15088", n=-1)
data['regionalkey_54'] = data['regionalkey_53'].str.replace("15265", "15088", n=-1)

data['regionalkey_55'] = data['regionalkey_54'].str.replace("15357", "15085", n=-1)
data['regionalkey_56'] = data['regionalkey_55'].str.replace("15364", "15085", n=-1)
data['regionalkey_57'] = data['regionalkey_56'].str.replace("15369", "15085", n=-1)

data['regionalkey_58'] = data['regionalkey_57'].str.replace("15151", "15091", n=-1)
data['regionalkey_59'] = data['regionalkey_58'].str.replace("15171", "15091", n=-1)

data['regionalkey_60'] = data['regionalkey_59'].str.replace("15202", "15002", n=-1)

data['regionalkey_61'] = data['regionalkey_60'].str.replace("15260", "15087", n=-1)
data['regionalkey_62'] = data['regionalkey_61'].str.replace("15266", "15087", n=-1)

data['regionalkey_63'] = data['regionalkey_62'].str.replace("15303", "15003", n=-1)
data['regionalkey_64'] = data['regionalkey_63'].str.replace("15358", "15086", n=-1)
data['regionalkey'] = data['regionalkey_64'].str.replace("15363", "15090", n=-1)

# %%
data=data[['BvDID_firm', 'year', 'plz_firm', 'ort', 'regionalkey', 'bundesland', 'BvDID_bank_1', 'postcode_bank_1', 'data2025_1',
       'data2075_1', 'data11750_1', 'data30680_1', 'data30690_1',
       'data38250_1', 'bank_type_1', 'liquidity_1', 'BvDID_bank_2',
       'postcode_bank_2', 'data2025_2', 'data2075_2', 'data11750_2',
       'data30680_2', 'data30690_2', 'data38250_2', 'bank_type_2',
       'liquidity_2', 'BvDID_bank_3', 'postcode_bank_3', 'data2025_3',
       'data2075_3', 'data11750_3', 'data30680_3', 'data30690_3',
       'data38250_3', 'bank_type_3', 'liquidity_3', 'fias', 'tfas', 'cash',
       'toas', 'shfd', 'ncli', 'ltdb', 'oncl', 'prov', 'culi', 'loan', 'cred',
       'wkca', 'ncas', 'empl', 'opre', 'turn', 'gros', 'staf', 'depr', 'cf',
       'rcem', 'rtas', 'dateinc_year_firm', 'sizecat', 'sector', 'adequacy',
       'hausbank', 'KID_firm', 'empllev', 'staflev', 'fiaslev', 'tfaslev',
       'cashlev', 'toaslev', 'provlev', 'ncaslev', 'turnlev', 'groslev',
       'deprlev', 'culilev', 'loanlev', 'credlev', 'nclilev', 'ltdblev',
       'oncllev', 'wkcalev', 'shfdlev', 'random', 'random_sample_indicator',
       'small', 'year_post', 'bank_ty_1', 'bank_ty_2', 'bank_ty_3',
       'bank_affected', 'bank_affected_degree']]
data
# Out:
#           BvDID_firm    year  plz_firm              ort regionalkey  \
# 1       DE2010019552  2010.0     90530             Roth       09576
# 2       DE2010019552  2011.0     90530             Roth       09576
# 3       DE2010019552  2012.0     90530             Roth       09576
# 4       DE2010019739  2012.0     15827   Teltow-Fläming       12072
# 5       DE2010035090  2010.0     12305    Berlin, Stadt       11000
# ...              ...     ...       ...              ...         ...
# 148109  DE8350268089  2012.0     85399         Freising       09178
# 148110  DE8350273540  2012.0     94362  Straubing-Bogen       09278
# 148111  DE8350275036  2012.0     84307       Rottal-Inn       09277
# 148112  DE8350276165  2012.0     84339       Rottal-Inn       09277
# 148113  DE8350277440  2012.0     70469        Stuttgart       08111
#
#                bundesland BvDID_bank_1 postcode_bank_1  data2025_1  \
# 1                  Bayern      DE13190           60311    623634.0
# 2                  Bayern      DE13190           60311    527219.0
# 3                  Bayern      DE13190           60311    525789.0
# 4             Brandenburg      DE13124           10787      9839.0
# 5                  Berlin      DE13885           30159     12353.0
# ...                   ...          ...             ...         ...
# 148109             Bayern      DE13338           85435      1835.0
# 148110             Bayern      DE13732           84028      3268.0
# 148111             Bayern      DE13772           84307      1679.0
# 148112             Bayern      DE13772           84307      1679.0
# 148113  Baden-Württemberg      DE13352           83022      4175.0
#
#         data2075_1  ...   shfdlev    random  random_sample_indicator  small  \
# 1         370294.0  ...  1.206676  0.824339                 0.627641      1
# 2         307754.0  ...  1.542198  0.063830                 0.627641      1
# 3         293639.0  ...  1.738739  0.538877                 0.627641      1
# 4            644.0  ...  1.691839  0.630216                 0.540324      1
# 5           1332.0  ...  0.023150  0.853153                 0.741225      1
# ...            ...  ...       ...       ...                      ...    ...
# 148109       150.0  ...  0.183207  0.982878                 0.733000      1
# 148110       564.0  ...  0.006883  0.832832                 0.598721      1
# 148111       241.0  ...  0.000000  0.436713                 0.500642      1
# 148112       241.0  ...  0.047464  0.552223                 0.642302      1
# 148113       256.0  ...  2.513060  0.992052                 0.897052      1
#
#        year_post  bank_ty_1 bank_ty_2 bank_ty_3  bank_affected  \
# 1              1          0         0         1              1
# 2              1          0         0         1              1
# 3              1          0         0         1              1
# 4              1          0         1         0              0
# 5              1          1         0         0              0
# ...          ...        ...       ...       ...            ...
# 148109         1          1         0         0              1
# 148110         1          1         0         0              1
# 148111         1          1         0         0              1
# 148112         1          1         0         0              1
# 148113         1          1         0         0              1
#
#         bank_affected_degree
# 1                          1
# 2                          1
# 3                          1
# 4                          0
# 5                          0
# ...                      ...
# 148109                     1
# 148110                     1
# 148111                     1
# 148112                     1
# 148113                     1
#
# [148113 rows x 93 columns]

# %%
data['ort_a'] = data['ort'].str.replace("Aachen, Stadt", "Aachen", n=-1)
data['ort_b'] = data['ort_a'].str.replace("Aachen", "Städteregion Aachen", n=-1)

data['ort_c'] = data['ort_b'].str.replace("Hamburg, Freie und Hansestadt", "Hamburg", n=-1)

data['ort_d'] = data['ort_c'].str.replace("Soltau-Fallingbostel", "Heidekreis", n=-1)

data['ort_e'] = data['ort_d'].str.replace("Oldenburg", "Oldenburg, Landkreis", n=-1)

data['ort_f'] = data['ort_e'].str.replace("Daun", "Vulkaneifel", n=-1)

data['ort_'] = data['ort_f'].str.replace(", Hansestadt", "", n=-1)

data.loc[(data.regionalkey == "09571") ,'ort_'] = 'Ansbach, Landkreis'
data.loc[(data.regionalkey == "13076") ,'ort_'] = 'Ludwigslust-Parchim'
data.loc[(data.regionalkey == "13073") ,'ort_'] = 'Vorpommern-Rügen'
data.loc[(data.regionalkey == "13075") ,'ort_'] = 'Vorpommern-Greifswald'
data.loc[(data.regionalkey == "14628") ,'ort_'] = 'Sächsische Schweiz-Osterzgebirge'

data.loc[(data.ort_ == "Chemnitz, Stadt") ,'regionalkey'] = '14511'
data.loc[(data.ort_ == "Dresden, Stadt") ,'regionalkey'] = '14612'
data.loc[(data.ort_ == "Leipzig, Stadt") ,'regionalkey'] = '14713'
data.loc[(data.ort_ == "Altmarkkreis Salzwedel") ,'regionalkey'] = '15081'
data.loc[(data.ort_ == "Göttingen") ,'regionalkey'] = '03159'
data.loc[(data.ort_ == "Bautzen") ,'regionalkey'] = '14625'
# Out:
# <ipython-input-23-d8aca8d9cd80>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ort_a'] = data['ort'].str.replace("Aachen, Stadt", "Aachen", n=-1)
# <ipython-input-23-d8aca8d9cd80>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ort_b'] = data['ort_a'].str.replace("Aachen", "Städteregion Aachen", n=-1)
# <ipython-input-23-d8aca8d9cd80>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ort_c'] = data['ort_b'].str.replace("Hamburg, Freie und Hansestadt", "Hamburg", n=-1)
# <ipython-input-23-d8aca8d9cd80>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ort_d'] = data['ort_c'].str.replace("Soltau-Fallingbostel", "Heidekreis", n=-1)
# <ipython-input-23-d8aca8d9cd80>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ort_e'] = data['ort_d'].str.replace("Oldenburg", "Oldenburg, Landkreis", n=-1)
# <ipython-input-23-d8aca8d9cd80>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ort_f'] = data['ort_e'].str.replace("Daun", "Vulkaneifel", n=-1)
# <ipython-input-23-d8aca8d9cd80>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ort_'] = data['ort_f'].str.replace(", Hansestadt", "", n=-1)
# /Users/effie/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)

# %%
data['regionalkey_a'] = data['regionalkey'].str.replace("05313", "05334", n=-1)
data['regionalkey_b'] = data['regionalkey_a'].str.replace("05354", "05334", n=-1)

data['regionalkey_c'] = data['regionalkey_b'].str.replace("2000", "2", n=-1)

data['regionalkey_'] = data['regionalkey_c'].str.replace("11000", "11", n=-1)



# 没有公司：
# 06413 Offenbach
# 07313 Landau in der Pfalz
# 07338 Rhein-Pfalz-Kreis
# 08125 Heilbronn, Landkreis
# 08215 Karlsruhe, Landkreis
# 09162 München
# 09363 Weiden i.d. OPf.
# Out:
# <ipython-input-24-1dd3a20b1340>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['regionalkey_a'] = data['regionalkey'].str.replace("05313", "05334", n=-1)
# <ipython-input-24-1dd3a20b1340>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['regionalkey_b'] = data['regionalkey_a'].str.replace("05354", "05334", n=-1)
# <ipython-input-24-1dd3a20b1340>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['regionalkey_c'] = data['regionalkey_b'].str.replace("2000", "2", n=-1)
# <ipython-input-24-1dd3a20b1340>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['regionalkey_'] = data['regionalkey_c'].str.replace("11000", "11", n=-1)

# %%
# ort_df = data[['regionalkey_','ort_']]
# data['regionalkey_'].value_counts()
# data['ort_'].value_counts()

# %%
# ort_df = ort_df.drop_duplicates()
# ort_df=ort_df.reset_index().drop(['index'], axis=1)
# ort_df.index=ort_df.index+1
# ort_df

# %%
#ort_df.to_csv(path_or_buf=r'/Users/mengxi/Desktop/financial research/final/211219_check county key.csv')

# %%
data=data[['BvDID_firm', 'year', 'plz_firm', 'ort_', 'regionalkey_', 'bundesland', 'BvDID_bank_1', 'postcode_bank_1', 'data2025_1',
       'data2075_1', 'data11750_1', 'data30680_1', 'data30690_1',
       'data38250_1', 'bank_type_1', 'liquidity_1', 'BvDID_bank_2',
       'postcode_bank_2', 'data2025_2', 'data2075_2', 'data11750_2',
       'data30680_2', 'data30690_2', 'data38250_2', 'bank_type_2',
       'liquidity_2', 'BvDID_bank_3', 'postcode_bank_3', 'data2025_3',
       'data2075_3', 'data11750_3', 'data30680_3', 'data30690_3',
       'data38250_3', 'bank_type_3', 'liquidity_3', 'fias', 'tfas', 'cash',
       'toas', 'shfd', 'ncli', 'ltdb', 'oncl', 'prov', 'culi', 'loan', 'cred',
       'wkca', 'ncas', 'empl', 'opre', 'turn', 'gros', 'staf', 'depr', 'cf',
       'rcem', 'rtas', 'dateinc_year_firm', 'sizecat', 'sector', 'adequacy',
       'hausbank', 'KID_firm', 'empllev', 'staflev', 'fiaslev', 'tfaslev',
       'cashlev', 'toaslev', 'provlev', 'ncaslev', 'turnlev', 'groslev',
       'deprlev', 'culilev', 'loanlev', 'credlev', 'nclilev', 'ltdblev',
       'oncllev', 'wkcalev', 'shfdlev', 'random', 'random_sample_indicator',
       'small', 'year_post', 'bank_ty_1', 'bank_ty_2', 'bank_ty_3',
       'bank_affected', 'bank_affected_degree']]
data
# Out:
#           BvDID_firm    year  plz_firm             ort_ regionalkey_  \
# 1       DE2010019552  2010.0     90530             Roth        09576
# 2       DE2010019552  2011.0     90530             Roth        09576
# 3       DE2010019552  2012.0     90530             Roth        09576
# 4       DE2010019739  2012.0     15827   Teltow-Fläming        12072
# 5       DE2010035090  2010.0     12305    Berlin, Stadt           11
# ...              ...     ...       ...              ...          ...
# 148109  DE8350268089  2012.0     85399         Freising        09178
# 148110  DE8350273540  2012.0     94362  Straubing-Bogen        09278
# 148111  DE8350275036  2012.0     84307       Rottal-Inn        09277
# 148112  DE8350276165  2012.0     84339       Rottal-Inn        09277
# 148113  DE8350277440  2012.0     70469        Stuttgart        08111
#
#                bundesland BvDID_bank_1 postcode_bank_1  data2025_1  \
# 1                  Bayern      DE13190           60311    623634.0
# 2                  Bayern      DE13190           60311    527219.0
# 3                  Bayern      DE13190           60311    525789.0
# 4             Brandenburg      DE13124           10787      9839.0
# 5                  Berlin      DE13885           30159     12353.0
# ...                   ...          ...             ...         ...
# 148109             Bayern      DE13338           85435      1835.0
# 148110             Bayern      DE13732           84028      3268.0
# 148111             Bayern      DE13772           84307      1679.0
# 148112             Bayern      DE13772           84307      1679.0
# 148113  Baden-Württemberg      DE13352           83022      4175.0
#
#         data2075_1  ...   shfdlev    random  random_sample_indicator  small  \
# 1         370294.0  ...  1.206676  0.824339                 0.627641      1
# 2         307754.0  ...  1.542198  0.063830                 0.627641      1
# 3         293639.0  ...  1.738739  0.538877                 0.627641      1
# 4            644.0  ...  1.691839  0.630216                 0.540324      1
# 5           1332.0  ...  0.023150  0.853153                 0.741225      1
# ...            ...  ...       ...       ...                      ...    ...
# 148109       150.0  ...  0.183207  0.982878                 0.733000      1
# 148110       564.0  ...  0.006883  0.832832                 0.598721      1
# 148111       241.0  ...  0.000000  0.436713                 0.500642      1
# 148112       241.0  ...  0.047464  0.552223                 0.642302      1
# 148113       256.0  ...  2.513060  0.992052                 0.897052      1
#
#        year_post  bank_ty_1 bank_ty_2 bank_ty_3  bank_affected  \
# 1              1          0         0         1              1
# 2              1          0         0         1              1
# 3              1          0         0         1              1
# 4              1          0         1         0              0
# 5              1          1         0         0              0
# ...          ...        ...       ...       ...            ...
# 148109         1          1         0         0              1
# 148110         1          1         0         0              1
# 148111         1          1         0         0              1
# 148112         1          1         0         0              1
# 148113         1          1         0         0              1
#
#         bank_affected_degree
# 1                          1
# 2                          1
# 3                          1
# 4                          0
# 5                          0
# ...                      ...
# 148109                     1
# 148110                     1
# 148111                     1
# 148112                     1
# 148113                     1
#
# [148113 rows x 93 columns]

# %%
# 所有data
# data.to_csv(path_or_buf=r'/Users/mengxi/Desktop/financial research/final/211219_firmdata.csv')

# %%
data0=data[data["year"]==2004]
id0=data0["BvDID_firm"].unique()
data1=data[data["year"]==2005]
id1=data1["BvDID_firm"].unique()
data2=data[data["year"]==2006]
id2=data2["BvDID_firm"].unique()
# data3=data[data["year"]==2007]
# id3=data3["BvDID_firm"].unique()
# data4=data[data["year"]==2008]
# id4=data4["BvDID_firm"].unique()

# %%
# id_all=set(list(id1)+list(id2)+list(id3)+list(id4))
# id_all=set(list(id1)+list(id2)+list(id3))
id_all=set(list(id0)+list(id1)+list(id2))

id_all
# Out:
# {'DE6110008825',
#  'DE3190001005',
#  'DE8270071196',
#  'DE4130008669',
#  'DE7330086955',
#  'DE5190186010',
#  'DE5010106309',
#  'DE8190048529',
#  'DE7330334620',
#  'DE5210001689',
#  'DE5330123213',
#data_useful.set_index(['BvDID_firm', 'year'], inplace=True)
data_useful=data_useful.reset_index().drop(['index'], axis=1)
data_useful.index=data_useful.index+1



data_useful
# Out:
#         BvDID_firm    year  plz_firm           ort_ regionalkey_ bundesland  \
# 1     DE2010041272  2006.0     13407  Berlin, Stadt           11     Berlin
# 2     DE2010041272  2007.0     13407  Berlin, Stadt           11     Berlin
# 3     DE2010041272  2008.0     13407  Berlin, Stadt           11     Berlin
# 4     DE2010041272  2009.0     13407  Berlin, Stadt           11     Berlin
# 5     DE2010041272  2010.0     13407  Berlin, Stadt           11     Berlin
# ...            ...     ...       ...            ...          ...        ...
# 7970  DE8350106575  2011.0     84056       Landshut        09274     Bayern
# 7971  DE8350106575  2012.0     84056       Landshut        09274     Bayern
# 7972  DE8350164094  2006.0     85356       Freising        09178     Bayern
# 7973  DE8350164094  2007.0     85356       Freising        09178     Bayern
# 7974  DE8350164094  2012.0     85356       Freising        09178     Bayern
#
#      BvDID_bank_1 postcode_bank_1  data2025_1  data2075_1  ...   shfdlev  \
# 1         DE13190           60311    265857.0     79992.0  ...  3.397223
# 2         DE13190           60311    302841.0    103003.0  ...  2.990665
# 3         DE13190           60311    359251.0    126692.0  ...  2.685565
# 4         DE13190           60311    605765.0    177120.0  ...  2.495652
# 5         DE13190           60311    623634.0    370294.0  ...  2.437330
# ...           ...             ...         ...         ...  ...       ...
# 7970      DE13732           84028      3274.0       548.0  ...  0.110567
# 7971      DE13732           84028      3268.0       564.0  ...  0.117222
# 7972      DE42769           85354      1159.0       102.0  ...  0.000000
# 7973      DE42769           85354      1190.0       144.0  ...  0.077424
# 7974      DE42769           85354      1258.0       102.0  ...  0.593000
#
#         random  random_sample_indicator  small year_post  bank_ty_1 bank_ty_2  \
# 1     0.061524                 0.575035      1         0          0         0
# 2     0.819242                 0.575035      1         0          0         0
# 3     0.925363                 0.575035      1         0          0         0
# 4     0.128524                 0.575035      1         1          0         0
# 5     0.728537                 0.575035      1         1          0         0
# ...        ...                      ...    ...       ...        ...       ...
# 7970  0.033535                 0.588138      1         1          1         0
# 7971  0.736541                 0.588138      1         1          1         0
# 7972  0.536886                 0.660865      1         0          1         0
# 7973  0.861183                 0.660865      1         0          1         0
# 7974  0.199183                 0.660865      1         1          1         0
#
#      bank_ty_3  bank_affected  bank_affected_degree
# 1            1              1                     1
# 2            1              1                     1
# 3            1              1                     1
# 4            1              1                     1
# 5            1              1                     1
# ...        ...            ...                   ...
# 7970         0              1                     1
# 7971         0              1                     1
# 7972         0              1                     1
# 7973         0              1                     1
# 7974         0              1                     1
#
# [7974 rows x 93 columns]

# %%
data_useful["cf_ratio"]=data_useful["cf"]/(data_useful["toaslev"]*10**6)
data_useful["gros_ratio"]=data_useful["groslev"]/(data_useful["toaslev"]*10**6)
data_useful["shfd_ratio"]=data_useful["shfdlev"]/data_useful["toaslev"]
data_useful["staf_ave"]=data_useful["staflev"]/data_useful["empllev"]
data_useful["staf_ln"]=np.log(data_useful["staf_ave"])

# recalculate toas in ln
data_useful["toas_lev"]=data_useful["toaslev"]+1
data_useful["toas_ln"]=np.log(data_useful["toas_lev"])

# sales in million
data_useful["turn_lev"]=(data_useful["turnlev"]/10**6)+1
data_useful["turn_ln"]=np.log(data_useful["turn_lev"])

# %%
data_useful
# Out:
#         BvDID_firm    year  plz_firm           ort_ regionalkey_ bundesland  \
# 1     DE2010041272  2006.0     13407  Berlin, Stadt           11     Berlin
# 2     DE2010041272  2007.0     13407  Berlin, Stadt           11     Berlin
# 3     DE2010041272  2008.0     13407  Berlin, Stadt           11     Berlin
# 4     DE2010041272  2009.0     13407  Berlin, Stadt           11     Berlin
# 5     DE2010041272  2010.0     13407  Berlin, Stadt           11     Berlin
# ...            ...     ...       ...            ...          ...        ...
# 7970  DE8350106575  2011.0     84056       Landshut        09274     Bayern
# 7971  DE8350106575  2012.0     84056       Landshut        09274     Bayern
# 7972  DE8350164094  2006.0     85356       Freising        09178     Bayern
# 7973  DE8350164094  2007.0     85356       Freising        09178     Bayern
# 7974  DE8350164094  2012.0     85356       Freising        09178     Bayern
#
#      BvDID_bank_1 postcode_bank_1  data2025_1  data2075_1  ...  \
# 1         DE13190           60311    265857.0     79992.0  ...
# 2         DE13190           60311    302841.0    103003.0  ...
# 3         DE13190           60311    359251.0    126692.0  ...
# 4         DE13190           60311    605765.0    177120.0  ...
# 5         DE13190           60311    623634.0    370294.0  ...
# ...           ...             ...         ...         ...  ...
# 7970      DE13732           84028      3274.0       548.0  ...
# 7971      DE13732           84028      3268.0       564.0  ...
# 7972      DE42769           85354      1159.0       102.0  ...
# 7973      DE42769           85354      1190.0       144.0  ...
# 7974      DE42769           85354      1258.0       102.0  ...
#
#       bank_affected_degree  cf_ratio  gros_ratio  shfd_ratio      staf_ave  \
# 1                        1  0.075024         NaN    0.042334  48871.675978
# 2                        1  0.091505         NaN    0.038756  49828.607527
# 3                        1  0.070409         NaN    0.031984  52628.015345
# 4                        1  0.061911         NaN    0.029387  44985.775956
# 5                        1  0.042470         NaN    0.027559  51404.482353
# ...                    ...       ...         ...         ...           ...
# 7970                     1  0.161112         NaN    0.202240  33063.769231
# 7971                     1  0.057209         NaN    0.216084  36853.846154
# 7972                     1  0.230300         NaN    0.000000  17312.543860
# 7973                     1  0.207050         NaN    0.076367  19426.391304
# 7974                     1       NaN         NaN    0.364251           NaN
#
#         staf_ln   toas_lev   toas_ln    turn_lev   turn_ln
# 1     10.796953  81.248314  4.397510  128.884630  4.858918
# 2     10.816345  78.166190  4.358837  150.773620  5.015780
# 3     10.871004  84.965980  4.442251  199.344200  5.295033
# 4     10.714102  85.924355  4.453467  119.532216  4.783586
# 5     10.847481  89.440920  4.493578  146.464800  4.986785
# ...         ...        ...       ...         ...       ...
# 7970  10.406193   1.546713  0.436132    2.317667  0.840561
# 7971  10.514715   1.542484  0.433394    2.320461  0.841766
# 7972   9.759187   2.136564  0.759199    5.152020  1.639389
# 7973   9.874388   2.013842  0.700044    6.110219  1.809963
# 7974        NaN   2.628000  0.966223         NaN       NaN
#
# [7974 rows x 102 columns]

# %%
data_check = data_useful[['BvDID_firm','year','bank_affected','empl','empllev','staf_ave','toas_ln','toas','toaslev','toas_lev','turn','turnlev','turn_lev','turn_ln','shfd_ratio','gros_ratio','cf_ratio','bank_affected_degree']]
data_check
# Out:
#         BvDID_firm    year  bank_affected      empl  empllev      staf_ave  \
# 1     DE2010041272  2006.0              1  5.883322    358.0  48871.675978
# 2     DE2010041272  2007.0              1  5.921578    372.0  49828.607527
# 3     DE2010041272  2008.0              1  5.971262    391.0  52628.015345
# 4     DE2010041272  2009.0              1  5.905362    366.0  44985.775956
# 5     DE2010041272  2010.0              1  5.831882    340.0  51404.482353
# ...            ...     ...            ...       ...      ...           ...
# 7970  DE8350106575  2011.0              1  2.639057     13.0  33063.769231
# 7971  DE8350106575  2012.0              1  2.639057     13.0  36853.846154
# 7972  DE8350164094  2006.0              1  4.060443     57.0  17312.543860
# 7973  DE8350164094  2007.0              1  4.248495     69.0  19426.391304
# 7974  DE8350164094  2012.0              1  4.127134     61.0           NaN
#
#        toas_ln       toas    toaslev   toas_lev       turn      turnlev  \
# 1     4.397510  18.200636  80.248314  81.248314  18.666639  127884630.0
# 2     4.358837  18.161472  77.166190  78.166190  18.824635  149773620.0
# 3     4.442251  18.245922  83.965980  84.965980  19.105514  198344200.0
# 4     4.453467  18.257271  84.924355  85.924355  18.590695  118532216.0
# 5     4.493578  18.297845  88.440920  89.440920  18.795445  145464800.0
# ...        ...        ...        ...        ...        ...          ...
# 7970  0.436132  13.211681   0.546713   1.546713  14.091374    1317667.0
# 7971  0.433394  13.203916   0.542484   1.542484  14.093492    1320461.0
# 7972  0.759199  13.943521   1.136564   2.136564  15.239106    4152020.0
# 7973  0.700044  13.829259   1.013842   2.013842  15.446753    5110219.0
# 7974  0.966223  14.302863   1.628000   2.628000        NaN          NaN
#
#         turn_lev   turn_ln  shfd_ratio  gros_ratio  cf_ratio  \
# 1     128.884630  4.858918    0.042334         NaN  0.075024
# 2     150.773620  5.015780    0.038756         NaN  0.091505
# 3     199.344200  5.295033    0.031984         NaN  0.070409
# 4     119.532216  4.783586    0.029387         NaN  0.061911
# 5     146.464800  4.986785    0.027559         NaN  0.042470
# ...          ...       ...         ...         ...       ...
# 7970    2.317667  0.840561    0.202240         NaN  0.161112
# 7971    2.320461  0.841766    0.216084         NaN  0.057209
# 7972    5.152020  1.639389    0.000000         NaN  0.230300
# 7973    6.110219  1.809963    0.076367         NaN  0.207050
# 7974         NaN       NaN    0.364251         NaN       NaN
#
#       bank_affected_degree
# 1                        1
# 2                        1
# 3                        1
# 4                        1
# 5                        1
# ...                    ...
# 7970                     1
# 7971                     1
# 7972                     1
# 7973                     1
# 7974                     1
#
# [7974 rows x 18 columns]

# %%
data_check_1 = data_check[['BvDID_firm','bank_affected','empllev','staf_ave','toas_lev','turn_lev','shfd_ratio','gros_ratio','cf_ratio','bank_affected_degree']]
data_check_1.describe()
# paper中，turn_lev平均为6.24，toas_lev平均为6.04，empllev平均为70
# Out:
#        bank_affected       empllev      staf_ave     toas_lev     turn_lev  \
# count    7974.000000   7974.000000  7.195000e+03  7974.000000  5823.000000
# mean        0.701781    235.136067  4.996740e+04    66.415423    73.637571
# std         0.457505    601.978368  1.069220e+05   271.393878   232.317716
# min         0.000000      1.000000  3.880000e+01     1.029278     1.000697
# 25%         0.000000     37.000000  3.638608e+04     6.970852    10.008145
# 50%         1.000000     84.000000  4.639338e+04    16.158465    23.328052
# 75%         1.000000    198.000000  5.644151e+04    47.842548    56.428260
# max         1.000000  11450.000000  7.873698e+06  6810.000000  5956.000000
#
#         shfd_ratio  gros_ratio     cf_ratio  bank_affected_degree
# count  7974.000000   82.000000  7033.000000           7974.000000
# mean      0.388376    0.588535     0.080575              0.735265
# std       0.234633    0.389193     0.163240              0.515427
# min       0.000000    0.082216    -3.273844              0.000000
# 25%       0.207489    0.291338     0.038088              0.000000
# 50%       0.370623    0.456251     0.072925              1.000000
# 75%       0.554272    1.004280     0.126171              1.000000
# max       0.994138    1.248863     3.100047              3.000000

# %%
data_useful.to_csv(path_or_buf=path+"firm_clean/ready_for_regression.csv")

# data_useful.to_csv(path_or_buf=r'/Users/mengxi/Desktop/financial research/final/211221_ready_for_regression.csv')

# %%
data_useful['bank_affected'].value_counts()
# Out:
# 1    5596
# 0    2378
# Name: bank_affected, dtype: int64

# %%
data_useful['bank_affected_degree'].value_counts()
# Out:
# 1    5345
# 0    2378
# 2     235
# 3      16
# Name: bank_affected_degree, dtype: int64

# %%
ddddddd
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-a0e138be22d3> in <module>
# ----> 1 ddddddd
#
# NameError: name 'ddddddd' is not defined

# %% [markdown]
# # County level data

# %%
group = data_useful.groupby('BvDID_firm')
affected_index = data_useful.groupby('BvDID_firm').mean()['bank_affected']
df = affected_index.to_frame('affected_index')

query_df = df.query('affected_index!=0')
df.loc[:,'affected_firm'] = df.index.map(lambda x : 1 if x in query_df.index else 0)
df
# Out:
#               affected_index  affected_firm
# BvDID_firm
# DE2010041272             1.0              1
# DE2010061796             1.0              1
# DE2010391850             0.0              0
# DE2010473501             0.0              0
# DE2010640945             0.0              0
# ...                      ...            ...
# DE8350087943             1.0              1
# DE8350093660             1.0              1
# DE8350104075             1.0              1
# DE8350106575             1.0              1
# DE8350164094             1.0              1
#
# [1267 rows x 2 columns]

# %%
df['affected_index'].value_counts()
# Out:
# 1.000000    877
# 0.000000    385
# 0.428571      1
# 0.857143      1
# 0.142857      1
# 0.500000      1
# 0.875000      1
# Name: affected_index, dtype: int64

# %%
df_1 = df.query('affected_index==0.5|affected_index==0.8|affected_index==0.75')

df_1
# Out:
#               affected_index  affected_firm
# BvDID_firm
# DE5290001074             0.5              1

# %%
data_1 = data.query('BvDID_firm=="DE2310133781"|BvDID_firm=="DE3290004653"')

data_1
# Out:
#          BvDID_firm    year  plz_firm        ort_ regionalkey_  \
# 20163  DE2310133781  2007.0     49143   Osnabrück        03459
# 20164  DE2310133781  2008.0     49143   Osnabrück        03459
# 20165  DE2310133781  2009.0     49143   Osnabrück        03459
# 20166  DE2310133781  2010.0     49143   Osnabrück        03459
# 20167  DE2310133781  2011.0     49143   Osnabrück        03459
# 20168  DE2310133781  2012.0     49143   Osnabrück        03459
# 38919  DE3290004653  2008.0      6886  Wittenberg        15091
# 38920  DE3290004653  2009.0      6886  Wittenberg        15091
# 38921  DE3290004653  2010.0      6886  Wittenberg        15091
# 38922  DE3290004653  2011.0      6886  Wittenberg        15091
# 38923  DE3290004653  2012.0      6886  Wittenberg        15091
#
#            bundesland BvDID_bank_1 postcode_bank_1  data2025_1  data2075_1  \
# 20163   Niedersachsen      DE13381           95444      2072.0       349.0
# 20164   Niedersachsen      DE13381           95444      2018.0       398.0
# 20165   Niedersachsen      DE13381           95444      2048.0       194.0
# 20166   Niedersachsen      DE13450           49324      1139.0       104.0
# 20167   Niedersachsen      DE13216           60325   1867699.0   1552399.0
# 20168   Niedersachsen      DE13450           49324      1148.0        65.0
# 38919  Sachsen-Anhalt      DE13696           59590       210.0        14.0
# 38920  Sachsen-Anhalt      DE13696           59590       232.0        23.0
# 38921  Sachsen-Anhalt      DE13696           59590       241.0        20.0
# 38922  Sachsen-Anhalt      DE13696           59590       254.0        26.0
# 38923  Sachsen-Anhalt      DE43071           06886      1277.0       240.0
#
#        ...   shfdlev    random  random_sample_indicator  small year_post  \
# 20163  ...  0.038126  0.797938                 0.706849      1         0
# 20164  ...  0.037362  0.877182                 0.706849      1         0
# 20165  ...  0.228036  0.280201                 0.706849      1         1
# 20166  ...  0.334857  0.524534                 0.706849      1         1
# 20167  ...  0.537464  0.990543                 0.706849      1         1
# 20168  ...  0.539362  0.463149                 0.706849      1         1
# 38919  ...  1.393655  0.773889                 0.757194      1         0
# 38920  ...  1.623327  0.861549                 0.757194      1         1
# 38921  ...  1.865229  0.915228                 0.757194      1         1
# 38922  ...  2.243508  0.757642                 0.757194      1         1
# 38923  ...  2.406114  0.704148                 0.757194      1         1
#
#        bank_ty_1 bank_ty_2 bank_ty_3  bank_affected  bank_affected_degree
# 20163          1         1         1              1                     1
# 20164          1         1         1              1                     1
# 20165          1         1         1              1                     1
# 20166          1         1         0              0                     0
# 20167          0         1         1              0                     0
# 20168          1         1         0              0                     0
# 38919          1         1         1              1                     1
# 38920          1         1         1              1                     1
# 38921          1         1         1              1                     1
# 38922          1         1         1              1                     1
# 38923          1         1         1              0                     0
#
# [11 rows x 93 columns]

# %%
group_1 = data_useful.groupby('regionalkey_')
firms_no = data_useful.groupby('regionalkey_').count()['BvDID_firm']
county_data_1 = firms_no.to_frame('firms_no')

data_2=data_useful[data_useful['bank_affected']==1]
data_2

firms_aff_no = data_2.groupby('regionalkey_').count()['bank_affected']
county_data_2 = firms_aff_no.to_frame('firms_aff_no')

county_data = pd.merge(left=county_data_1, right=county_data_2, on='regionalkey_', how='left')

county_data['ratio']=county_data["firms_aff_no"]/county_data["firms_no"]

# %%
county_data
# Out:
#               firms_no  firms_aff_no  ratio
# regionalkey_
# 01001                2           2.0    1.0
# 01002               20          20.0    1.0
# 01003               15          15.0    1.0
# 01004               26          26.0    1.0
# 01053               14          14.0    1.0
# ...                ...           ...    ...
# 16072                4           4.0    1.0
# 16073               26           NaN    NaN
# 16074                7           NaN    NaN
# 16076                7           NaN    NaN
# 16077                8           8.0    1.0
#
# [301 rows x 3 columns]

# %%
county_data.to_csv(path_or_buf=path+"firm_clean/key for county identification.csv")
