# %%
import pandas as pd 
import numpy as np

# %%
path="/Users/effie/Desktop/term3/research_module/data/"
firm_data=pd.read_csv(path+"firm_clean/key for county identification.csv")
firm_data=firm_data.rename(columns={"regionalkey_": "Regional-key"})

# %%
county_employee=pd.read_excel(path+"/county_raw/total/Employed_domestic_Total.xlsx") 
county_employee_total= pd.merge(left=county_employee, right=firm_data, on='Regional-key', how='left')
county_employee_total.to_csv(path_or_buf=path+"county_clean/ready_county_employee.csv")
county_employee_total
# Out:
#      Lfd. Nr. EU-Code  Regional-key Land  \
# 0           1     DE1             8   BW
# 1           2    DE11            81   BW
# 2           3   DE111          8111   BW
# 3           4   DE112          8115   BW
# 4           5   DE113          8116   BW
# ..        ...     ...           ...  ...
# 440       441   DEG0L         16076   TH
# 441       442   DEG0M         16077   TH
# 442       443   DEG0N         16056   TH
# 443       444   DEG0P         16063   TH
# 444       445      DE            17    D
#
#                               Gebietseinheit     1992     1994     1995  \
# 0                          Baden-Württemberg  5230.59  5104.32  5116.34
# 1                Stuttgart, Regierungsbezirk  2046.86   1981.5  1982.39
# 2    Stuttgart, Landeshauptstadt, Stadtkreis  486.895  456.649  450.453
# 3                       Böblingen, Landkreis  188.312  180.966  180.821
# 4                       Esslingen, Landkreis  237.498  228.491  229.239
# ...

# %%
county_gdp=pd.read_excel(path+"/county_raw/total/gdp_Change_compare.xlsx")
county_gdp_total= pd.merge(left=county_gdp, right=firm_data, on='Regional-key', how='left')
county_gdp_total.to_csv(path_or_buf=path+"county_clean/ready_county_gdp.csv")
county_gdp_total
# Out:
#                                               Lfd. Nr. EU-Code  Regional-key  \
# 0                                                  NaN     NaN           NaN
# 1                                                    1     DE1           8.0
# 2                                                    2    DE11          81.0
# 3                                                    3   DE111        8111.0
# 4                                                    4   DE112        8115.0
# ..                                                 ...     ...           ...
# 443                                                443   DEG0N       16056.0
# 444                                                444   DEG0P       16063.0
# 445                                                445      DE          17.0
# 446                                                NaN     NaN           NaN
# 447  1) Angaben zum Wartburgkreis bis 1995 einschli...     NaN           NaN
#
# ...

# %%
county_emp_agr=pd.read_excel(path+"/county_raw/by_industry/employed_agriculture.xlsx")
county_emp_agr_total= pd.merge(left=county_emp_agr, right=firm_data, on='Regional-key', how='left')
county_emp_agr_total.to_csv(path_or_buf=path+"county_clean/ready_county_emp_agr.csv")
county_emp_agr_total
# Out:
#      Lfd. Nr. EU-Code  Regional-key Land  \
# 0           1     DE1             8   BW
# 1           2    DE11            81   BW
# 2           3   DE111          8111   BW
# 3           4   DE112          8115   BW
# 4           5   DE113          8116   BW
# ..        ...     ...           ...  ...
# 440       441   DEG0L         16076   TH
# 441       442   DEG0M         16077   TH
# 442       443   DEG0N         16056   TH
# 443       444   DEG0P         16063   TH
# 444       445      DE            17    D
#
#                               Gebietseinheit industry     1992     1994  \
# 0                          Baden-Württemberg        A  129.711  120.258
# 1                Stuttgart, Regierungsbezirk        A        .        .
# 2    Stuttgart, Landeshauptstadt, Stadtkreis        A        .        .
# 3                       Böblingen, Landkreis        A        .        .
# 4                       Esslingen, Landkreis        A        .        .
# ...

# %%
county_emp_man=pd.read_excel(path+"/county_raw/by_industry/employed_manufacturing.xlsx")
county_emp_man_total= pd.merge(left=county_emp_man, right=firm_data, on='Regional-key', how='left')
county_emp_man_total.to_csv(path_or_buf=path+"county_clean/ready_county_emp_man.csv")
county_emp_man
# Out:
#      Lfd. Nr. EU-Code  Regional-key Land  \
# 0           1     DE1             8   BW
# 1           2    DE11            81   BW
# 2           3   DE111          8111   BW
# 3           4   DE112          8115   BW
# 4           5   DE113          8116   BW
# ..        ...     ...           ...  ...
# 440       441   DEG0L         16076   TH
# 441       442   DEG0M         16077   TH
# 442       443   DEG0N         16056   TH
# 443       444   DEG0P         16063   TH
# 444       445      DE            17    D
#
#                               Gebietseinheit    1992     1994     1995  \
# 0                          Baden-Württemberg  2121.2  1932.87  1900.48
# 1                Stuttgart, Regierungsbezirk       .        .        .
# 2    Stuttgart, Landeshauptstadt, Stadtkreis       .        .        .
# 3                       Böblingen, Landkreis       .        .        .
# 4                       Esslingen, Landkreis       .        .        .
# ...

# %%
county_emp_ser=pd.read_excel(path+"/county_raw/by_industry/employed_service.xlsx")
county_emp_ser_total= pd.merge(left=county_emp_ser, right=firm_data, on='Regional-key', how='left')
county_emp_ser_total.to_csv(path_or_buf=path+"county_clean/ready_county_emp_ser.csv")
county_emp_ser
# Out:
#      Lfd. Nr. EU-Code  Regional-key Land  \
# 0           1     DE1             8   BW
# 1           2    DE11            81   BW
# 2           3   DE111          8111   BW
# 3           4   DE112          8115   BW
# 4           5   DE113          8116   BW
# ..        ...     ...           ...  ...
# 440       441   DEG0L         16076   TH
# 441       442   DEG0M         16077   TH
# 442       443   DEG0N         16056   TH
# 443       444   DEG0P         16063   TH
# 444       445      DE            17    D
#
#                               Gebietseinheit     1992    1994     1995  \
# 0                          Baden-Württemberg  2979.68  3051.2  3104.61
# 1                Stuttgart, Regierungsbezirk        .       .        .
# 2    Stuttgart, Landeshauptstadt, Stadtkreis        .       .        .
# 3                       Böblingen, Landkreis        .       .        .
# 4                       Esslingen, Landkreis        .       .        .
# ...

# %%
county_gva_agr=pd.read_excel(path+"/county_raw/by_industry/gva_agriculture.xlsx")
county_gva_agr_total= pd.merge(left=county_gva_agr, right=firm_data, on='Regional-key', how='left')
county_gva_agr_total.to_csv(path_or_buf=path+"county_clean/ready_county_gva_agr.csv")
county_gva_agr
# Out:
#                                               Lfd. Nr. EU-Code  Regional-key  \
# 0                                                  NaN     NaN           NaN
# 1                                                    1     DE1           8.0
# 2                                                    2    DE11          81.0
# 3                                                    3   DE111        8111.0
# 4                                                    4   DE112        8115.0
# ..                                                 ...     ...           ...
# 443                                                443   DEG0N       16056.0
# 444                                                444   DEG0P       16063.0
# 445                                                445      DE          17.0
# 446                                                NaN     NaN           NaN
# 447  1) Angaben zum Wartburgkreis bis 1995 einschli...     NaN           NaN
#
# ...

# %%
county_gva_man=pd.read_excel(path+"/county_raw/by_industry/gva_manufacturing.xlsx")
county_gva_man_total= pd.merge(left=county_gva_man, right=firm_data, on='Regional-key', how='left')
county_gva_man_total.to_csv(path_or_buf=path+"county_clean/ready_county_gva_man.csv")
county_gva_man
# Out:
#                                               Lfd. Nr. EU-Code  Regional-key  \
# 0                                                    1     DE1           8.0
# 1                                                    2    DE11          81.0
# 2                                                    3   DE111        8111.0
# 3                                                    4   DE112        8115.0
# 4                                                    5   DE113        8116.0
# ..                                                 ...     ...           ...
# 442                                                443   DEG0N       16056.0
# 443                                                444   DEG0P       16063.0
# 444                                                445      DE          17.0
# 445                                                NaN     NaN           NaN
# 446  1) Angaben zum Wartburgkreis bis 1995 einschli...     NaN           NaN
#
# ...

# %%
county_gva_ser=pd.read_excel(path+"/county_raw/by_industry/gva_service.xlsx")
county_gva_ser_total= pd.merge(left=county_gva_ser, right=firm_data, on='Regional-key', how='left')
county_gva_ser_total.to_csv(path_or_buf=path+"county_clean/ready_county_gva_ser.csv")
county_gva_ser
# Out:
#                                               Lfd. Nr. EU-Code  Regional-key  \
# 0                                                  NaN     NaN           NaN
# 1                                                    1     DE1           8.0
# 2                                                    2    DE11          81.0
# 3                                                    3   DE111        8111.0
# 4                                                    4   DE112        8115.0
# ..                                                 ...     ...           ...
# 443                                                443   DEG0N       16056.0
# 444                                                444   DEG0P       16063.0
# 445                                                445      DE          17.0
# 446                                                NaN     NaN           NaN
# 447  1) Angaben zum Wartburgkreis bis 1995 einschli...     NaN           NaN
#
# ...
